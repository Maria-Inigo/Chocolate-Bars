# %% [markdown]
# # Best Chocolate Bar

# %% [markdown]
# ## Table of Content:
# * [Set Up](#1)
#    * [External Modules](#1.1)
#    * [Data Import](#1.2)
# * [Exploratory Data Analysis](#2)
#    * [Missing Data](#2.2)

# %% [markdown]
# ### Set Up <a class="anchor" id="1"></a>

# %% [markdown]
# #### External Modules <a class="anchor" id="1.1"></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Import Data <a class="anchor" id="1.2"></a>

# %%
df = pd.read_csv('../Data/chocolate_ratings.csv')

df.head()
# Out:
#     REF Company (Manufacturer) Company Location  Review Date  \
# 0  2454                   5150           U.S.A.         2019
# 1  2458                   5150           U.S.A.         2019
# 2  2454                   5150           U.S.A.         2019
# 3  2542                   5150           U.S.A.         2021
# 4  2546                   5150           U.S.A.         2021
#
#   Country of Bean Origin Specific Bean Origin or Bar Name Cocoa Percent  \
# 0               Tanzania            Kokoa Kamili, batch 1           76%
# 1     Dominican Republic                  Zorzal, batch 1           76%
# 2             Madagascar           Bejofo Estate, batch 1           76%
# 3                   Fiji            Matasawalevu, batch 1           68%
# 4              Venezuela            Sur del Lago, batch 1           72%
#
#   Ingredients     Most Memorable Characteristics  Rating
# 0    3- B,S,C          rich cocoa, fatty, bready    3.25
# 1    3- B,S,C             cocoa, vegetal, savory    3.50
# 2    3- B,S,C       cocoa, blackberry, full body    3.75
# 3    3- B,S,C                chewy, off, rubbery    3.00
# 4    3- B,S,C  fatty, earthy, moss, nutty,chalky    3.00

# %% [markdown]
# ### Exploratory Data Analysis <a class="anchor" id="2"></a>

# %% [markdown]
# To simplify the future uses of each column, first I'm going to rename some of the titles so that there are no white spaces.

# %%
df.rename(columns = {
  'Company (Manufacturer)': 'Company', 
  'Company Location':'Company_Location',
  'Review Date': 'Year_Reviewed',
  'Country of Bean Origin': 'Bean_Origin',
  'Specific Bean Origin or Bar Name': 'Bar_Name',
  'Cocoa Percent': 'Cocoa_Percent',
  'Most Memorable Characteristics': 'Characteristics',
}, inplace = True)

df.head()
# Out:
#     REF Company Company_Location  Year_Reviewed         Bean_Origin  \
# 0  2454    5150           U.S.A.           2019            Tanzania
# 1  2458    5150           U.S.A.           2019  Dominican Republic
# 2  2454    5150           U.S.A.           2019          Madagascar
# 3  2542    5150           U.S.A.           2021                Fiji
# 4  2546    5150           U.S.A.           2021           Venezuela
#
#                  Bar_Name Cocoa_Percent Ingredients  \
# 0   Kokoa Kamili, batch 1           76%    3- B,S,C
# 1         Zorzal, batch 1           76%    3- B,S,C
# 2  Bejofo Estate, batch 1           76%    3- B,S,C
# 3   Matasawalevu, batch 1           68%    3- B,S,C
# 4   Sur del Lago, batch 1           72%    3- B,S,C
#
#                      Characteristics  Rating
# 0          rich cocoa, fatty, bready    3.25
# 1             cocoa, vegetal, savory    3.50
# 2       cocoa, blackberry, full body    3.75
# 3                chewy, off, rubbery    3.00
# 4  fatty, earthy, moss, nutty,chalky    3.00

# %% [markdown]
# #### Missing Data <a class="anchor" id="2.2"></a>

# %%
df.isnull().sum() * 100 / len(df)
# Out:
# REF                 0.000000
# Company             0.000000
# Company_Location    0.000000
# Year_Reviewed       0.000000
# Bean_Origin         0.000000
# Bar_Name            0.000000
# Cocoa_Percent       0.000000
# Ingredients         3.438735
# Characteristics     0.000000
# Rating              0.000000
# dtype: float64

# %%
df[df.isna().any(axis=1)]
# Out:
#        REF                         Company Company_Location  Year_Reviewed  \
# 85    1964                   Amazing Cacao           Russia           2017
# 86    1964                   Amazing Cacao           Russia           2017
# 164    486             Artisan du Chocolat             U.K.           2010
# 293     81                          Bonnat           France           2006
# 323    341          Bouga Cacao (Tulicorp)          Ecuador           2009
# ...    ...                             ...              ...            ...
# 2424   153  Vintage Plantations (Tulicorp)           U.S.A.           2007
# 2425   153  Vintage Plantations (Tulicorp)           U.S.A.           2007
# 2426   153  Vintage Plantations (Tulicorp)           U.S.A.           2007
# 2447   733                      Whittakers      New Zealand           2011
# 2457  1109                  Willie's Cacao             U.K.           2013
#
#      Bean_Origin                           Bar_Name Cocoa_Percent Ingredients  \
# 85          Peru                            Maranon           70%         NaN
# 86          Peru                        Platan Bajo           70%         NaN
# 164    Venezuela                          Venezuela          100%         NaN
# 293        Blend                        One Hundred          100%         NaN
# 323      Ecuador            El Oro, Hacienda de Oro          100%         NaN
# ...          ...                                ...           ...         ...
# 2424     Ecuador  Los Rios, Rancho Grande 2004/2007          100%         NaN
# 2425     Ecuador  Los Rios, Rancho Grande 2004/2007           90%         NaN
# 2426     Ecuador  Los Rios, Rancho Grande 2004/2007           75%         NaN
# 2447       Ghana                              Ghana           72%         NaN
# 2457   Indonesia             Java, Indonesian Black          100%         NaN
#
#                        Characteristics  Rating
# 85                    raisins, pungent    3.00
# 86    few grits, blackcherry, licorice    3.50
# 164            very nutty, very bitter    1.75
# 293                acidic, bitter, dry    1.50
# 323     cardboard, very bitter, floral    1.50
# ...                                ...     ...
# 2424  bland, mild fruit, strong bitter    2.00
# 2425         some fruit, strong bitter    2.00
# 2426      cocoa,earthy,very astringent    3.00
# 2447    sticky, dry, vanilla dominates    2.50
# 2457       fruit, strong smoke, bitter    2.25
#
# [87 rows x 10 columns]

# %% [markdown]
# Since there are only 3.47% of bars with empty ingredients data, I'll drop those rows.

# %%
df = df.dropna()

df.isnull().sum() * 100 / len(df)
# Out:
# REF                 0.0
# Company             0.0
# Company_Location    0.0
# Year_Reviewed       0.0
# Bean_Origin         0.0
# Bar_Name            0.0
# Cocoa_Percent       0.0
# Ingredients         0.0
# Characteristics     0.0
# Rating              0.0
# dtype: float64

# %% [markdown]
# #### Redundant Columns <a class="anchor" id="2.2"></a>

# %% [markdown]
# The content of some columns can be divided in different details, like the specific bean origin and the batch and the ingredients.

# %%
df[['S_Bean_Origin', 'Batch']] = df['Bar_Name'].str.split(', batch', expand=True)
df.drop(['Bar_Name'], axis=1)

df[['Number_Ingredients', 'Ingredients']] = df['Ingredients'].str.split('- ', expand=True)

df.head()
# Out:
#     REF Company Company_Location  Year_Reviewed         Bean_Origin  \
# 0  2454    5150           U.S.A.           2019            Tanzania
# 1  2458    5150           U.S.A.           2019  Dominican Republic
# 2  2454    5150           U.S.A.           2019          Madagascar
# 3  2542    5150           U.S.A.           2021                Fiji
# 4  2546    5150           U.S.A.           2021           Venezuela
#
#                  Bar_Name Cocoa_Percent Ingredients  \
# 0   Kokoa Kamili, batch 1           76%       B,S,C
# 1         Zorzal, batch 1           76%       B,S,C
# 2  Bejofo Estate, batch 1           76%       B,S,C
# 3   Matasawalevu, batch 1           68%       B,S,C
# 4   Sur del Lago, batch 1           72%       B,S,C
#
#                      Characteristics  Rating  S_Bean_Origin Batch  \
# 0          rich cocoa, fatty, bready    3.25   Kokoa Kamili     1
# 1             cocoa, vegetal, savory    3.50         Zorzal     1
# 2       cocoa, blackberry, full body    3.75  Bejofo Estate     1
# 3                chewy, off, rubbery    3.00   Matasawalevu     1
# 4  fatty, earthy, moss, nutty,chalky    3.00   Sur del Lago     1
#
#   Number_Ingredients
# 0                  3
# 1                  3
# 2                  3
# 3                  3
# 4                  3

# %% [markdown]
# The ingredients seem to have repetitive elements as well, so I might be able to divide them.

# %%
df['Ingredients'].unique()
# Out:
# array(['B,S,C', 'B,S,C,L', 'B,S', 'B,S,C,V', 'B,S,C,V,L', None, nan,
#        'B,S,V,L', 'B,S*', 'B', 'B,S*,C', 'B,S,L', 'B,S,V', 'B,S*,C,L',
#        'B,S*,C,Sa', 'B,S*,Sa', 'B,S,C,Sa', 'B,S*,V,L', 'B,C', 'B,S*,C,V',
#        'B,S,C,L,Sa'], dtype=object)

# %%
df = df.dropna()

print(df.isnull().sum() * 100 / len(df))
print(df['Ingredients'].unique())
# Out:
# REF                   0.0
# Company               0.0
# Company_Location      0.0
# Year_Reviewed         0.0
# Bean_Origin           0.0
# Bar_Name              0.0
# Cocoa_Percent         0.0
# Ingredients           0.0
# Characteristics       0.0
# Rating                0.0
# S_Bean_Origin         0.0
# Number_Ingredients    0.0
# dtype: float64
# ['B,S,C' 'B,S,C,L' 'B,S' 'B,S,C,V' 'B,S,C,V,L' 'B,S,V,L' 'B,S*' 'B'
#  'B,S*,C' 'B,S,L' 'B,S,V' 'B,S*,C,L' 'B,S*,C,Sa' 'B,S*,Sa' 'B,S,C,Sa'
#  'B,S*,V,L' 'B,C' 'B,S*,C,V' 'B,S,C,L,Sa']

# %% [markdown]
# We got rid of the missing values. Since the components of the chocolate bars are not many (B, S, C, L, V, S, S*, Sa) and they are quite repetitive the ingredients can also be separated in dummies and it won't enlarge too much the dataframe.

# %%
df = df.join(df['Ingredients'].str.get_dummies(sep=',').add_prefix('Ingredient_'))

df.head()
# Out:
#     REF Company Company_Location  Year_Reviewed         Bean_Origin  \
# 0  2454    5150           U.S.A.           2019            Tanzania
# 1  2458    5150           U.S.A.           2019  Dominican Republic
# 2  2454    5150           U.S.A.           2019          Madagascar
# 3  2542    5150           U.S.A.           2021                Fiji
# 4  2546    5150           U.S.A.           2021           Venezuela
#
#                  Bar_Name Cocoa_Percent Ingredients  \
# 0   Kokoa Kamili, batch 1           76%       B,S,C
# 1         Zorzal, batch 1           76%       B,S,C
# 2  Bejofo Estate, batch 1           76%       B,S,C
# 3   Matasawalevu, batch 1           68%       B,S,C
# 4   Sur del Lago, batch 1           72%       B,S,C
#
#                      Characteristics  Rating  S_Bean_Origin  \
# 0          rich cocoa, fatty, bready    3.25   Kokoa Kamili
# 1             cocoa, vegetal, savory    3.50         Zorzal
# 2       cocoa, blackberry, full body    3.75  Bejofo Estate
# 3                chewy, off, rubbery    3.00   Matasawalevu
# 4  fatty, earthy, moss, nutty,chalky    3.00   Sur del Lago
#
#   Number_Ingredients  Ingredient_B  Ingredient_C  Ingredient_L  Ingredient_S  \
# 0                  3             1             1             0             1
# 1                  3             1             1             0             1
# 2                  3             1             1             0             1
# 3                  3             1             1             0             1
# 4                  3             1             1             0             1
#
#    Ingredient_S*  Ingredient_Sa  Ingredient_V
# 0              0              0             0
# 1              0              0             0
# 2              0              0             0
# 3              0              0             0
# 4              0              0             0

# %% [markdown]
# We have columns with repeated data, let's drop those.

# %%
df = df.drop(columns=['Ingredients', 'Bar_Name'])

df.head()
# Out:
#     REF Company Company_Location  Year_Reviewed         Bean_Origin  \
# 0  2454    5150           U.S.A.           2019            Tanzania
# 1  2458    5150           U.S.A.           2019  Dominican Republic
# 2  2454    5150           U.S.A.           2019          Madagascar
# 3  2542    5150           U.S.A.           2021                Fiji
# 4  2546    5150           U.S.A.           2021           Venezuela
#
#   Cocoa_Percent                    Characteristics  Rating  S_Bean_Origin  \
# 0           76%          rich cocoa, fatty, bready    3.25   Kokoa Kamili
# 1           76%             cocoa, vegetal, savory    3.50         Zorzal
# 2           76%       cocoa, blackberry, full body    3.75  Bejofo Estate
# 3           68%                chewy, off, rubbery    3.00   Matasawalevu
# 4           72%  fatty, earthy, moss, nutty,chalky    3.00   Sur del Lago
#
#   Number_Ingredients  Ingredient_B  Ingredient_C  Ingredient_L  Ingredient_S  \
# 0                  3             1             1             0             1
# 1                  3             1             1             0             1
# 2                  3             1             1             0             1
# 3                  3             1             1             0             1
# 4                  3             1             1             0             1
#
#    Ingredient_S*  Ingredient_Sa  Ingredient_V
# 0              0              0             0
# 1              0              0             0
# 2              0              0             0
# 3              0              0             0
# 4              0              0             0

# %% [markdown]
# The data is almost ready, the last thing I'm going to do is remove the percentage symbol from the `Cocoa_Percent` column and convert the values to numbers.

# %%
df['Cocoa_Percent'] = list(map(lambda x: x[:-1], df['Cocoa_Percent'].values))

df.head()
# Out:
#     REF Company Company_Location  Year_Reviewed         Bean_Origin  \
# 0  2454    5150           U.S.A.           2019            Tanzania
# 1  2458    5150           U.S.A.           2019  Dominican Republic
# 2  2454    5150           U.S.A.           2019          Madagascar
# 3  2542    5150           U.S.A.           2021                Fiji
# 4  2546    5150           U.S.A.           2021           Venezuela
#
#   Cocoa_Percent                    Characteristics  Rating  S_Bean_Origin  \
# 0            76          rich cocoa, fatty, bready    3.25   Kokoa Kamili
# 1            76             cocoa, vegetal, savory    3.50         Zorzal
# 2            76       cocoa, blackberry, full body    3.75  Bejofo Estate
# 3            68                chewy, off, rubbery    3.00   Matasawalevu
# 4            72  fatty, earthy, moss, nutty,chalky    3.00   Sur del Lago
#
#   Number_Ingredients  Ingredient_B  Ingredient_C  Ingredient_L  Ingredient_S  \
# 0                  3             1             1             0             1
# 1                  3             1             1             0             1
# 2                  3             1             1             0             1
# 3                  3             1             1             0             1
# 4                  3             1             1             0             1
#
#    Ingredient_S*  Ingredient_Sa  Ingredient_V
# 0              0              0             0
# 1              0              0             0
# 2              0              0             0
# 3              0              0             0
# 4              0              0             0

# %% [markdown]
# I want to make sure that the numeric values are defined as so.

# %%
df.dtypes
# Out:
# REF                     int64
# Company                object
# Company_Location       object
# Year_Reviewed           int64
# Bean_Origin            object
# Cocoa_Percent          object
# Characteristics        object
# Rating                float64
# S_Bean_Origin          object
# Number_Ingredients     object
# Ingredient_B            int64
# Ingredient_C            int64
# Ingredient_L            int64
# Ingredient_S            int64
# Ingredient_S*           int64
# Ingredient_Sa           int64
# Ingredient_V            int64
# dtype: object

# %% [markdown]
# The number of ingredients should be int type. And the cocoa percent could be an int or a float.
#
# The company might also be changed but I have to check that.

# %%
df['Cocoa_Percent'].unique()
# Out:
# array(['76', '68', '72', '80', '70', '63', '74', '60', '88', '55', '75',
#        '85', '73', '64', '66', '50', '77', '82', '65', '90', '71', '83',
#        '78', '86', '62', '69', '91', '100', '67', '42', '61', '73.5',
#        '79', '58', '71.50', '60.5', '81', '57', '56', '46', '89', '99',
#        '84', '53', '87'], dtype=object)

# %%
df['Company'].unique()
# Out:
# array(['5150', 'A. Morin', 'Acalli', 'Adi aka Fijiana (Easy In Ltd)',
#        'Aelan', 'Aequare (Gianduja)', 'Ah Cacao', "Akesson's (Pralus)",
#        'Alain Ducasse', 'Alexandre', 'Altus aka Cao Artisan', 'Amano',
#        'Amatller (Simon Coll)', 'Amazona', 'Ambrosia', 'Amedei', 'AMMA',
#        'Anahata', 'Animas', 'Ara', 'Arete', 'Argencove',
#        'Artisan du Chocolat', 'Artisan du Chocolat (Casa Luker)',
#        'Aruntam', 'Askinosie', 'Atypic', 'Auro', 'Avanaa', 'Bahen & Co.',
#        'Baiani', 'Bakau', 'Bankston', 'Bar Au Chocolat', "Baravelli's",
#        'Batch', 'Bean', 'Beau Cacao', 'Beehive', 'Belcolade',
#        'Bellflower', 'Belvie', 'Belyzium', 'Benns', 'Benoit Nihant',
#        'Bernachon', 'Beschle (Felchlin)', 'Bisou', 'Bitacora',
#        'Bittersweet Origins', 'Bixby', 'Black Mountain',
#        'Black River (A. Morin)', 'Black Sheep', 'Blanxart',
#        'Blue Bandana', 'Boho', 'Bonaterra', 'Bonnat',
#        'Bouga Cacao (Tulicorp)', 'Brasstown',
#        "Brasstown aka It's Chocolate", 'Brazen', 'Breeze Mill', 'Bright',
#        'Britarev', 'Bronx Grrl Chocolate', 'Bullion', 'Burnt Fork Bend',
#        'By Cacao', 'Cacai Cacao', 'Cacao 70', 'Cacao Arabuco',
#        'Cacao Atlanta', 'Cacao Barry', 'Cacao Betulia', 'Cacao de Origen',
#        'Cacao Gonzales', 'Cacao Hunters', 'Cacao Market', 'Cacao Prieto',
#        'Cacao Sampaka', 'Cacao Santa Fe (Art of Chocolate)',
#        'Cacao Store', 'Cacaosuyo', 'Cacaoyere (Ecuatoriana)', 'C-Amaro',
#        'Cao', 'Caofiori', 'Caoni (Tulicorp)', 'Captain Pembleton',
#        'CAR Artisan', 'Caribeans', 'Carlotta Chocolat', 'Casa',
#        'Casa Lasevicius', 'Castronovo', 'Cello', 'Chaleur B', 'Chapon',
#        'Charm School', 'Chchukululu (Tulicorp)', 'Chequessett',
#        'Chocablog', 'Choco Del Sol', 'Choco Dong', 'Chococard (Lapos)',
#        'Chocolarder', "Chocola'te", 'Chocolate Alchemist-Philly',
#        'Chocolate Con Amor', 'Chocolate Conspiracy', 'Chocolate Makers',
#        'Chocolate Tree', 'Chocolates by Josh (Box Chocolate)',
#        'Chocolatoa', 'Chocolats Privilege', 'Chocolibrium', 'Chocosol',
#        'Chocotenango', 'Chocovic', 'Chocovivo', 'Choklat', 'Chokola',
#        'Chokolat Elot (Girard)', 'Christophe Toury', 'Christopher Elbow',
#        'Chuao Chocolatier', 'Chuao Chocolatier (Pralus)',
#        'Claudio Corallo', 'Cleveland Chocolate Company', 'Cloudforest',
#        'Coco', 'Cocoa Carib', 'Cocoa Forge', 'Condor', 'Confluence',
#        'Conjure', 'Coppeneur', 'Cravve', 'Creo', 'Crow and Moss',
#        'Cultura', 'Cuna de Piedra', 'Daintree', 'Dalloway', 'Damson',
#        'Dancing Lion', 'Dandelion', 'Dandelion (aka Brower Ave)',
#        'Dandelion (Japan)', 'Danta', 'DAR', 'Darcis', 'Dark Forest',
#        'Davis', 'De Mendes', 'De Villiers', 'Dean and Deluca (Belcolade)',
#        'Debauve & Gallais (Michel Cluizel)', 'Definite', 'Desbarres',
#        'DeVries', 'Dick Taylor', 'Diogo Vaz', 'Doble & Bignall',
#        'Dolfin (Belcolade)', 'Domori', 'Dormouse', 'Double Spiral',
#        "Duffy's", 'Dulcinea', 'Durci', 'East Van Roasters', 'Eau de Rose',
#        'Eclat (Felchlin)', 'Eclat (Fruition)', 'Edelmond', 'El Buen',
#        'El Ceibo', 'El Rey', 'Eldora', 'Emerald Estate', "Emily's",
#        'Encuentro', 'ENNA', 'Erithaj (A. Morin)', 'Escazu',
#        "Ethel's Artisan (Mars)", 'Ethereal', 'Exquisito',
#        'Fearless (AMMA)', 'Feitoria Cacao', 'Felchlin', 'Finca', 'Finnia',
#        'Firetree', 'Five (5)Mile', 'FJAK', 'Forever Cacao', 'Fossa',
#        'Foundry', 'Franceschi', 'Frederic Blondeel', 'French Broad',
#        'Fresco', 'Fresh Coast', 'Fresh Coast aka Just Good Choc.',
#        'Friis Holm', 'Friis Holm (Bonnat)', 'Fruition', 'Fu Wan',
#        'Garden Island', 'Georgia Ramon', 'Glennmade', 'Goodnow Farms',
#        'Gotham', 'Grand Place', 'Great Lakes', "Green & Black's (ICAM)",
#        'Green Bean to Bar', 'Green Door', 'Grenada Chocolate Co.',
#        'Guido Castagna', 'Guittard', 'Habitual', 'Hachez',
#        'Hacienda El Castillo', 'Harper Macaw', 'Harris & James',
#        'Hazel Hill', 'Hecho', 'Heilemann', 'Heinde & Verre',
#        'Heirloom Cacao Preservation (Brasstown)',
#        'Heirloom Cacao Preservation (Fruition)',
#        'Heirloom Cacao Preservation (Guittard)',
#        'Heirloom Cacao Preservation (Manoa)',
#        'Heirloom Cacao Preservation (Millcreek)',
#        'Heirloom Cacao Preservation (Mindo)',
#        'Heirloom Cacao Preservation (Zokoko)',
#        'hello cocoa (now Markham & Fitz)', 'Hemisphere', 'hexx',
#        'Hogarth', 'Hoja Verde (Tulicorp)', 'Holy Cacao', 'Honest',
#        'Hotel Chocolat', 'Hotel Chocolat (Coppeneur)', 'Hummingbird',
#        'Idilio (Felchlin)', 'Indah', 'Indi', 'iQ Chocolate', 'Isidro',
#        'Islands Chocolate', 'Izard', 'Jacque Torres',
#        'Jean Marie Auboine', 'Johnny Iuzzini', 'Jordis', 'Kad Kokoa',
#        'Kah Kow', 'Kah Kow - USA', 'Kaitxo', 'Kallari (Ecuatoriana)',
#        'Kasama', 'Kerchner', "Ki' Xocolatl", 'Kin + Pod', 'Kiskadee',
#        'Krak', 'Kto', "K'ul", 'L.A. Burdick (Felchlin)',
#        'La Cascade du Chocolat', 'La Chorena', 'La Feverie (Hasnaa)',
#        'La Maison du Chocolat (Valrhona)', 'La Rifa',
#        'Laia aka Chat-Noir', "L'Amourette", 'Land', 'Landmark (Amano)',
#        'Legast', 'Letterpress', 'Levy', 'Lilla', 'Lillie Belle',
#        'Lindt & Sprungli', 'Lirio', 'Loiza', 'Lonohana', 'Loon',
#        'Love Bar', 'Love Brown', 'Luisa Abram', "Luisa's Vegan", 'Luker',
#        'Lumineux', 'MaDe Atlantic City Chocolate Bar',
#        'Madecasse (Cinagra)', 'Madhu', 'Madre', 'Maglio', 'Majani',
#        'Malagasy (Chocolaterie Robert)', 'Malagos', 'Malai',
#        'Malie Kai (Guittard)', 'Malmo', 'Mana', 'Manifesto Cacao',
#        'Manoa', 'Manufaktura Czekolady', 'Map Chocolate', 'Marana',
#        'Maribea', "Marigold's Finest", 'Markham & Fitz', 'Marou',
#        'Marsatta', 'Martin Mayer', 'Mast Brothers', 'Matale', 'Maui Kuia',
#        'Maverick', 'Mayacama', 'McGuire', 'Meadowlands', 'Mellow',
#        'Menakao (aka Cinagra)', 'Mesocacao', 'Mestico', 'Metiisto',
#        'Metropolitan', 'Meybol', 'Michel Cluizel', 'Middlebury',
#        'Mike & Becky', 'Millcreek Cacao Roasters', 'Millesime', 'Milton',
#        'Mindo', 'Minimal', 'Mirzam', 'Misina', 'Mission', 'Moho',
#        'Moka Origins', 'Moku', 'Molucca', 'Momotombo', 'Monarque',
#        'Monsoon', 'MUCHO', 'Muchomas (Mesocacao)',
#        'Musee du Chocolat Theobroma', 'Mutari', 'Nahua', 'Naive',
#        'Nathan Miller', 'Nearynogs', 'Neuhaus (Callebaut)', 'Nibble',
#        'Night Owl', 'Nikoa', 'Nina', 'Ninth (9th) & Larkin',
#        'Noble Bean aka Jerjobo', 'Nova Monda', 'Nuance', 'Nugali',
#        'Oakland Chocolate Co.', 'Obolo', 'Ocelot', 'Ocho', 'Odyssey',
#        'Ohiyo', 'Oialla by Bojessen (Malmo)', 'Olive and Sinclair',
#        'Olivia', 'Omanhene', 'Omnom', 'Or Dubh', 'Orfeve', 'organicfair',
#        'Original Beans (Felchlin)', 'Original Hawaiin Chocolate Factory',
#        'Orquidea', 'Pacari', "Palet D'Or", 'Palette de Bine', 'Pangea',
#        'Park 75', 'Parliament', 'Parre Chocolat', 'Pascha', 'Patric',
#        'Paul Young', 'Peppalo', 'Perrenial', 'Petite Patrie',
#        'Pierre Marcolini', 'Piety and Desire', 'Pinellas', 'Pitch Dark',
#        'Pollinator', 'Pomm (aka Dead Dog)', 'Poppy and Peep', 'Potomac',
#        'Pralus', 'Primo Botanica', 'Public Chocolatory',
#        'Pump Street Bakery', 'Pura Delizia', 'Q Chocolate', 'Qantu',
#        'Quetzalli (Wolter)', 'Raaka', 'Rain Republic', 'Ranger',
#        'Raoul Boulanger', 'Raphio', 'Republica del Cacao (aka Confecta)',
#        'Ritual', 'River-Sea', 'Roasting Masters',
#        'Robert (aka Chocolaterie Robert)', 'Rogue', 'Rozsavolgyi',
#        'Ruket', 'Sacred', 'Salgado', 'San Jose',
#        'Santander (Compania Nacional)', 'Santome', 'Scharffen Berger',
#        'Seaforth', 'Seahorse', 'Shane Chocolate Works', 'Shark Mountain',
#        "Shark's", 'Shattell', 'Sibu', 'Silvio Bessone', 'Sirene',
#        'Sjolinds', 'Smooth Chocolator, The', 'Snake & Butterfly', 'Soeka',
#        'Soklet', 'Sol Cacao', 'Solkiki', 'Solomons Gold', 'Solstice',
#        'Soma', 'Somerville', 'Soul', 'Spagnvola', 'Spencer', 'Spinnaker',
#        'Sprungli (Felchlin)', 'SRSLY', 'Starchild',
#        'Stella (aka Bernrain)', 'Stone Grindz', 'StRita Supreme',
#        'Sublime Origins', 'Summerbird', 'Suruca Chocolate',
#        'Svenska Kakaobolaget', 'sweet beans', 'Sweet Escalier',
#        'Sweetness', 'Szanto Tibor', 'Tabal',
#        'Tablette (aka Vanillabeans)', 'Tala', 'Tan Ban Skrati',
#        'Taste Artisan', 'Taste Artisan aka Coleman and Davis',
#        'Taucherli', 'Taylor Made', 'Taza', 'TCHO', 'Tejas', 'Terroir',
#        'The Barn', 'Theo', 'Theobroma', 'Thistle & Rose aka Aggie USU',
#        'Tibito', 'Timo A. Meyer', 'Tiny House', "To'ak",
#        "To'ak (Ecuatoriana)", 'Tocoti', 'Tosier', 'Tree to Bar',
#        'Treehouse', 'Treehouse aka Indaphoria', 'Triangle Roasters',
#        'Tribar', 'Tribe', 'twenty-four blackbirds', 'Two Ravens',
#        'Uncouth', 'Undone', 'Upchurch', 'Urzi', 'Utopick', 'Vaka',
#        'Valrhona', 'Vao Vao (Chocolaterie Robert)', 'Vicuna', 'Videri',
#        'Vietcacao (A. Morin)', 'Vintage Plantations',
#        'Vintage Plantations (Tulicorp)', 'Violet Sky', 'Vivra',
#        'Wellington Chocolate Factory', 'White Label aka Mutari',
#        "Wilkie's Organic", "Willie's Cacao", 'Wm', 'Woodblock', 'Xocolat',
#        'Xocolatisimo', 'Xocolatl', 'Xocolla', 'Zac Squared', 'Zacharias',
#        "Zak's", 'Zart Pralinen', 'Zokoko', 'Zoto (Chocolatoa)', 'Zotter'],
#       dtype=object)

# %% [markdown]
# I'll go with float for the cocoa percent since there are some values that are not exact.
#
# On the other hand, the company can not be a number type.

# %%
df['Cocoa_Percent'] = df['Cocoa_Percent'].astype(float)
df['Number_Ingredients'] = df['Number_Ingredients'].astype(int)

df.dtypes
# Out:
# REF                     int64
# Company                object
# Company_Location       object
# Year_Reviewed           int64
# Bean_Origin            object
# Cocoa_Percent         float64
# Characteristics        object
# Rating                float64
# S_Bean_Origin          object
# Number_Ingredients      int64
# Ingredient_B            int64
# Ingredient_C            int64
# Ingredient_L            int64
# Ingredient_S            int64
# Ingredient_S*           int64
# Ingredient_Sa           int64
# Ingredient_V            int64
# dtype: object

# %% [markdown]
# Now that the data is as I like, I'm going to save it in a new file.

# %%
df.to_csv('../Data/processed_data.csv', index=False)
